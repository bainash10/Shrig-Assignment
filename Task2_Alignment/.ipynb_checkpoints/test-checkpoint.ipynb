# %% [markdown]
# # 1. Importing Dependencies

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Loading the input image

# %%
image = cv2.imread("input.png")

# %%
# image
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
plt.imshow(image)  # display image using matplotlib imshow function

# %% [markdown]
# # 3. Image preprocessing

# %% [markdown]
# ## a. Grayscale Conversion

# %%
# The image is in RGB so we need to convert it to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# gray = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# %%
gray
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
plt.imshow(gray)

# %% [markdown]
# ## b. Gaussian Blur

# %%
blur = cv2.GaussianBlur(gray, (5,5), 0) #this reduces noise
# here gray is the image that is converted to grayscale
# (5,5) is the kernel size, kernel size is width and height, always should be odd numbers and positive, Larger values = more blur, but also more loss of detail
# 0 is the signmaX which means Standard Deviation in X drn
# choosen 0 - because 0 tells opencv to automatically calculate sigmaX based on the kernel size.
# If set it to a value > 0, controls how "spread out" or say how thick the blur is.

# %%
plt.imshow(blur)

# %%
## c. Edge Detection using Canny Edge Detector
